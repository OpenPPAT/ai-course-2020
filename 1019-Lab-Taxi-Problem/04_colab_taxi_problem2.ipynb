# %% [markdown]
# # Introduce to OpenAI Gym with DuckieNav Environment
#
#
# We will introduce the main API methods in gym:
# * `reset()`
# * `step()`
# * `render()`
#
# ![hi](https://drive.google.com/uc?id=193KoOaA5YPOha8TnxdHXDXgsciIcSuzV)
#
# and the essentials in RL:
# * Environment
# * State
# * Action
# * Reward
# * Agent
#
#
#
# ### Environment
# The example is modifed from the Taxi Problem in "Hierarchical Reinforcement Learning with the MAXQ Value Function Decomposition" by  Tom Dietterich (2000), Journal of Artificial Intelligence Research.
#
# <!--img style="float: right;" src="images/DuckieNav-v1.png"  width="240" height="240"-->
#
#
# ```
# MAP = [
#     "+-----------------+",
#     "|O|O| : : : : :G: |",
#     "|O|O| |O| |O| |O| |",
#     "|O| : |O| |O| |O| |",
#     "| : |O|O| : : : : |",
#     "| |O|O|O|O|O| |O| |",
#     "| : :R: : : : |O| |",
#     "| |O|O|O| |O|O|O| |",
#     "| |O| : : |O| : : |",
#     "| |O| |O|O|O|B|O| |",
#     "| : : : : : : |O| |",
#     "| |O| |O| |O| |O| |",
#     "| : : : : : : |O| |",
#     "| |O| |O| |O|O|O| |",
#     "| : : :Y: : : : : |",
#     "+-----------------+",
# ]
# ```
#
# We consider shows a 14 by 9 grid world, except the "service area." The taxi problem is episodic, and in each episode a passenger is located at one of the 4 specially designated locations (R, Y, B, and G). The taxi(agent) starts in a given location and must go to the transported passenger’s location, pick up the passenger, go to the destination location, and put down the passenger. The episode ends when the passenger is deposited at the destination location to one of the 4 locations.
#
#
# Adapted from https://www.oreilly.com/learning/introduction-to-reinforcement-learning-and-openai-gym

# %% [markdown]
# ## 0. Understand OpenAI Gym and Tests

# %%
# !python --version
# !pytest --version
# Out:
# Python 2.7.17
# This is pytest version 3.6.4, imported from /usr/local/lib/python2.7/dist-packages/pytest.pyc

# %%
# %%file test_math.py

import math
def test_add():
    assert 1+1 == 2

def test_mul():
    assert 6*7 == 42

def test_sin():
    assert math.sin(0) == 0
# Out:
# Writing test_math.py

# %%
# !python -m pytest test_math.py
# Out:
# ============================= test session starts ==============================
# platform linux2 -- Python 2.7.17, pytest-3.6.4, py-1.8.0, pluggy-0.7.1
# rootdir: /content, inifile:
# collected 3 items
#
# test_math.py ...                                                         [100%]
#
# =========================== 3 passed in 0.03 seconds ===========================

# %% [markdown]
# Running pytest for gym can be easily carried out in the container built by the provided Dockerfile. Unfortunately docker is not fully supported in Colab. Please try those **on your local machine (not Colab)**:
#
#
# ```
# mkdir dockerfiles
# cd dockerfiles
# git clone https://github.com/openai/gym.git
# cd gym
# docker build -f py.Dockerfile -t gym-test --build-arg PYTHON_VER=3.8.1 .
# docker run gym-test
# ```

# %% [markdown]
# ## 1. Initialize DuckieNav-v0
#
# ### Installation
# You can obtain and install this customized gym environment (https://github.com/ARG-NCTU/gym-duckienav.git):

# %%
# !git clone https://github.com/ARG-NCTU/gym-duckienav.git
# %cd gym-duckienav
# !pip install -e .
# Out:
# Cloning into 'gym-duckienav'...
# remote: Enumerating objects: 5, done.
# remote: Counting objects: 100% (5/5), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 96 (delta 0), reused 4 (delta 0), pack-reused 91
# Unpacking objects: 100% (96/96), done.
# /content/gym-duckienav
# Obtaining file:///content/gym-duckienav
# Requirement already satisfied: gym in /usr/local/lib/python2.7/dist-packages (from gym-duckienav==0.0.1) (0.10.11)
# Requirement already satisfied: scipy in /usr/local/lib/python2.7/dist-packages (from gym->gym-duckienav==0.0.1) (1.2.2)
# Requirement already satisfied: six in /usr/local/lib/python2.7/dist-packages (from gym->gym-duckienav==0.0.1) (1.15.0)
# Requirement already satisfied: requests>=2.0 in /usr/local/lib/python2.7/dist-packages (from gym->gym-duckienav==0.0.1) (2.23.0)
# Requirement already satisfied: pyglet>=1.2.0 in /usr/local/lib/python2.7/dist-packages (from gym->gym-duckienav==0.0.1) (1.4.1)
# Requirement already satisfied: numpy>=1.10.4 in /usr/local/lib/python2.7/dist-packages (from gym->gym-duckienav==0.0.1) (1.16.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python2.7/dist-packages (from requests>=2.0->gym->gym-duckienav==0.0.1) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python2.7/dist-packages (from requests>=2.0->gym->gym-duckienav==0.0.1) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python2.7/dist-packages (from requests>=2.0->gym->gym-duckienav==0.0.1) (2019.6.16)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python2.7/dist-packages (from requests>=2.0->gym->gym-duckienav==0.0.1) (2.8)
# Requirement already satisfied: future in /usr/local/lib/python2.7/dist-packages (from pyglet>=1.2.0->gym->gym-duckienav==0.0.1) (0.16.0)
# Installing collected packages: gym-duckienav
#   Running setup.py develop for gym-duckienav
# Successfully installed gym-duckienav

# %%
import gym
import gym_duckienav
import gym.spaces
import numpy as np

#env = gym.make("DuckieNav-v2")
env = gym.make("DuckieNav-v0")
#env = gym.make("Taxi-v2")

# %% [markdown]
# ### How many 'states' in observation_space:
# There are 2520 states from: 14 (rows) x 9 (columns) x 5 (passenger locations: R, Y, B, G, or on taxi) x 4 (destinations: R, Y, B, or G)

# %%
env.observation_space.n
# Out:
# 2520

# %% [markdown]
# ### action_space:
# There are 6 possible actions in Taxi-v2 environment
# * down (0), up (1), right (2), left (3), pick-up (4), and drop-off (5)

# %%
env.action_space.n
# Out:
# 6

# %% [markdown]
# ## 2. States
#
# Resets the state of the environment and returns an initial observation (state).
#
# The current state is from :
# * current taxi row position
# * current taxi colum position
# * passenger location (Blue or in taxi) from 0: R, 1: G, 2: Y, 3: B; 4: in taxi.
# * destination location (Magenta) from 0: R, 1: G, 2: Y, 3: B

# %%
env.reset()

print "Current state: " + str(env.s)
for p in env.decode(env.s): print p
env.render()
# Out:
# Current state: 228
# 1
# 2
# 2
# 0
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+

# %% [markdown]
# Repeat previous cell for a few times.
#
# In taxi problem, the colors mean:
# * blue: passenger's current position
# * magenta: destination
# * yellow: empty taxi
# * green: full taxi

# %% [markdown]
# ## 3. Actions
#
# Remember that the taxi agent can perform the following actions:
# * 0: "South",
# * 1: "North",
# * 2: "East",
# * 3: "West",
# * 4: "Pickup",
# * 5: "Dropoff"
#
# Let's set the state to 124.
# Let the taxi agent perform some actions.

# %%
ACTIONS = ["South", "North", "East", "West", "Pickup", "Dropoff"]
env.s = 124
env.render()
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : |O| |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (Dropoff)

# %% [markdown]
# ### `step()`
#
# Run one timestep of the environment's dynamics.
# It returns a tuple (observation, reward, done, info)
# * observation (object): agent's observation of the current environment
# * reward (float) : amount of reward returned after previous action
# * done (boolean): whether the episode has ended, in which case further step() calls will return undefined results
# * info (dict): contains auxiliary diagnostic information (helpful for debugging, and sometimes learning)
#
# Essentially the empty taxi is supposed to:
# * move toward the blue letter,
# * pickup the passenger (now the taxi is green),
# * drive to the magenta letter, and
# * drop the passenger (the taxi is yellow again).
#
# It is obvious that we should start with moving "East" env.step(2). Index 2 is for moving "East"
# We will do the followings:
# * Perform "Pickup" step(4) (although the passenger is not here)
# * Perform "East" step(2)
# * Perform "Pickup" step(4)
# * Perform "West" step(3)
# * Perform "South" step(0) for 5 times
# * Perfomr "Dropoff" (5)
# * Perform "West" step(3) for 4 times
# * Perfomr "Dropoff" (5)

# %%
state, reward, done, info = env.step(4)
env.render()
print "reward: " + str(reward)
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (Pickup)
# reward: -10

# %%
state, reward, done, info = env.step(2)
env.render()
print "reward: " + str(reward)
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (East)
# reward: -1

# %%
state, reward, done, info = env.step(4)
env.render()
print "reward: " + str(reward)
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (Pickup)
# reward: -1

# %%
state, reward, done, info = env.step(3)
env.render()
print "reward: " + str(reward)
# Out:
# +-----------------+
# |O|O| : : : :_:G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (West)
# reward: -1

# %%
for i in range(0, 5):
    env.step(0)
env.render()
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : :_:O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (South)

# %%
state, reward, done, info = env.step(5)
env.render()
print "reward: " + str(reward)
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : :_:O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (Dropoff)
# reward: -10

# %%
for i in range(0, 4):
    env.step(3)
env.render()
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (West)

# %%
state, reward, done, info = env.step(5)
env.render()
print "reward: " + str(reward)
print "done: " + str(done)
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (Dropoff)
# reward: 20
# done: True

# %% [markdown]
# ### Rewards
#
# You have probably figured out the rewards:
# * Perform any movements: -1
# * Pick up or drop off at the wrong position: -10
# * Drop off the passenger at the right position: 20

# %% [markdown]
# ## 4. Ramdon Agent:
#
# We will use the funciton env.action_space.sample(); you could run the following cell for a few times

# %%
print env.action_space.sample()
# Out:
# 0

# %% [markdown]
# ### How good does behaving completely random do?

# %%
state = env.reset()

counter = 0
g = 0
reward = None
while reward != 20:
    state, reward, done, info = env.step(env.action_space.sample())
    counter += 1
    g += reward
print("Solved in {} Steps with a total reward of {}".format(counter,g))
# Out:
# Solved in 7158 Steps with a total reward of -189015

# %% [markdown]
# You may luck out and solve the environment fairly quickly, but on average, a completely random policy will solve this environment in about ???? steps

# %% [markdown]
# ## 5. Agent with Basic Reinforcement Learning: Q-Learning
#
# In order to maximize our reward, we will have to have the algorithm remember its actions and their associated rewards. Here, the algorithm’s memory is going to be a Q action value table.
#
# To manage this Q table, we will use a NumPy array. The size of this table will be the number of states (2520) by the number of possible actions (6).

# %%
n_states = env.observation_space.n
n_actions = env.action_space.n
Q = np.zeros([n_states, n_actions])
ACTIONS = ["South", "North", "East", "West", "Pickup", "Dropoff"]

episodes = 1
G = 0
counter = 0
alpha = 0.618

for episode in range(1,episodes+1):
    done = False
    G, reward = 0,0

    state = env.reset()
    env.render()
    print("Step: {}, Action: {}, Reward: {}, Q[{}] \t{}".format("   ", "   ", "   ", "   ", ACTIONS))

    firstState = state
    print("Initial State = {}".format(state))
    while reward != 20:
        action = np.argmax(Q[state])  #1
        state2, reward, done, info = env.step(action) #2

        if counter < 20:
            print("Before Step: {}, Action: {}, Reward: {}, Q[{}] \t{}".format(counter, ACTIONS[action], reward, state, Q[state]))
            print("Future Step: {}, Action: {}, Reward: {}, Q[{}] \t{}".format(counter, ACTIONS[action], reward, state2, Q[state2]))

        Q[state,action] += alpha * (reward + np.max(Q[state2]) - Q[state,action]) #3
        
        if counter < 20:
            print("After  Step: {}, Action: {}, Reward: {}, Q[{}] \t{}".format(counter, ACTIONS[action], reward, state, Q[state]))
            print("--------")

        counter += 1
        G += reward
        state = state2
        
finalState = state
print("Final State = {}".format(finalState))
print("Solved in {} Steps with a total reward of {}".format(counter, G))
env.render()

print ACTIONS
print Q[finalState]
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#
# Step:    , Action:    , Reward:    , Q[   ] 	['South', 'North', 'East', 'West', 'Pickup', 'Dropoff']
# Initial State = 1794
# Before Step: 0, Action: South, Reward: -1, Q[1794] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 0, Action: South, Reward: -1, Q[1974] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 0, Action: South, Reward: -1, Q[1794] 	[-0.618  0.     0.     0.     0.     0.   ]
# --------
# Before Step: 1, Action: South, Reward: -1, Q[1974] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 1, Action: South, Reward: -1, Q[2154] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 1, Action: South, Reward: -1, Q[1974] 	[-0.618  0.     0.     0.     0.     0.   ]
# --------
# Before Step: 2, Action: South, Reward: -1, Q[2154] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 2, Action: South, Reward: -1, Q[2334] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 2, Action: South, Reward: -1, Q[2154] 	[-0.618  0.     0.     0.     0.     0.   ]
# --------
# Before Step: 3, Action: South, Reward: -1, Q[2334] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 3, Action: South, Reward: -1, Q[2514] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 3, Action: South, Reward: -1, Q[2334] 	[-0.618  0.     0.     0.     0.     0.   ]
# --------
# Before Step: 4, Action: South, Reward: -1, Q[2514] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 4, Action: South, Reward: -1, Q[2514] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 4, Action: South, Reward: -1, Q[2514] 	[-0.618  0.     0.     0.     0.     0.   ]
# --------
# Before Step: 5, Action: North, Reward: -1, Q[2514] 	[-0.618  0.     0.     0.     0.     0.   ]
# Future Step: 5, Action: North, Reward: -1, Q[2334] 	[-0.618  0.     0.     0.     0.     0.   ]
# After  Step: 5, Action: North, Reward: -1, Q[2514] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# --------
# Before Step: 6, Action: North, Reward: -1, Q[2334] 	[-0.618  0.     0.     0.     0.     0.   ]
# Future Step: 6, Action: North, Reward: -1, Q[2154] 	[-0.618  0.     0.     0.     0.     0.   ]
# After  Step: 6, Action: North, Reward: -1, Q[2334] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# --------
# Before Step: 7, Action: North, Reward: -1, Q[2154] 	[-0.618  0.     0.     0.     0.     0.   ]
# Future Step: 7, Action: North, Reward: -1, Q[1974] 	[-0.618  0.     0.     0.     0.     0.   ]
# After  Step: 7, Action: North, Reward: -1, Q[2154] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# --------
# Before Step: 8, Action: North, Reward: -1, Q[1974] 	[-0.618  0.     0.     0.     0.     0.   ]
# Future Step: 8, Action: North, Reward: -1, Q[1794] 	[-0.618  0.     0.     0.     0.     0.   ]
# After  Step: 8, Action: North, Reward: -1, Q[1974] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# --------
# Before Step: 9, Action: North, Reward: -1, Q[1794] 	[-0.618  0.     0.     0.     0.     0.   ]
# Future Step: 9, Action: North, Reward: -1, Q[1614] 	[0. 0. 0. 0. 0. 0.]
# After  Step: 9, Action: North, Reward: -1, Q[1794] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# --------
# Before Step: 10, Action: South, Reward: -1, Q[1614] 	[0. 0. 0. 0. 0. 0.]
# Future Step: 10, Action: South, Reward: -1, Q[1794] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# After  Step: 10, Action: South, Reward: -1, Q[1614] 	[-0.618  0.     0.     0.     0.     0.   ]
# --------
# Before Step: 11, Action: East, Reward: -1, Q[1794] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# Future Step: 11, Action: East, Reward: -1, Q[1794] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# After  Step: 11, Action: East, Reward: -1, Q[1794] 	[-0.618 -0.618 -0.618  0.     0.     0.   ]
# --------
# Before Step: 12, Action: West, Reward: -1, Q[1794] 	[-0.618 -0.618 -0.618  0.     0.     0.   ]
# Future Step: 12, Action: West, Reward: -1, Q[1794] 	[-0.618 -0.618 -0.618  0.     0.     0.   ]
# After  Step: 12, Action: West, Reward: -1, Q[1794] 	[-0.618 -0.618 -0.618 -0.618  0.     0.   ]
# --------
# Before Step: 13, Action: Pickup, Reward: -10, Q[1794] 	[-0.618 -0.618 -0.618 -0.618  0.     0.   ]
# Future Step: 13, Action: Pickup, Reward: -10, Q[1794] 	[-0.618 -0.618 -0.618 -0.618  0.     0.   ]
# After  Step: 13, Action: Pickup, Reward: -10, Q[1794] 	[-0.618 -0.618 -0.618 -0.618 -6.18   0.   ]
# --------
# Before Step: 14, Action: Dropoff, Reward: -10, Q[1794] 	[-0.618 -0.618 -0.618 -0.618 -6.18   0.   ]
# Future Step: 14, Action: Dropoff, Reward: -10, Q[1794] 	[-0.618 -0.618 -0.618 -0.618 -6.18   0.   ]
# After  Step: 14, Action: Dropoff, Reward: -10, Q[1794] 	[-0.618 -0.618 -0.618 -0.618 -6.18  -6.18 ]
# --------
# Before Step: 15, Action: South, Reward: -1, Q[1794] 	[-0.618 -0.618 -0.618 -0.618 -6.18  -6.18 ]
# Future Step: 15, Action: South, Reward: -1, Q[1974] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# After  Step: 15, Action: South, Reward: -1, Q[1794] 	[-0.854076 -0.618    -0.618    -0.618    -6.18     -6.18    ]
# --------
# Before Step: 16, Action: East, Reward: -1, Q[1974] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# Future Step: 16, Action: East, Reward: -1, Q[1974] 	[-0.618 -0.618  0.     0.     0.     0.   ]
# After  Step: 16, Action: East, Reward: -1, Q[1974] 	[-0.618 -0.618 -0.618  0.     0.     0.   ]
# --------
# Before Step: 17, Action: West, Reward: -1, Q[1974] 	[-0.618 -0.618 -0.618  0.     0.     0.   ]
# Future Step: 17, Action: West, Reward: -1, Q[1974] 	[-0.618 -0.618 -0.618  0.     0.     0.   ]
# After  Step: 17, Action: West, Reward: -1, Q[1974] 	[-0.618 -0.618 -0.618 -0.618  0.     0.   ]
# --------
# Before Step: 18, Action: Pickup, Reward: -10, Q[1974] 	[-0.618 -0.618 -0.618 -0.618  0.     0.   ]
# Future Step: 18, Action: Pickup, Reward: -10, Q[1974] 	[-0.618 -0.618 -0.618 -0.618  0.     0.   ]
# After  Step: 18, Action: Pickup, Reward: -10, Q[1974] 	[-0.618 -0.618 -0.618 -0.618 -6.18   0.   ]
# --------
# Before Step: 19, Action: Dropoff, Reward: -10, Q[1974] 	[-0.618 -0.618 -0.618 -0.618 -6.18   0.   ]
# Future Step: 19, Action: Dropoff, Reward: -10, Q[1974] 	[-0.618 -0.618 -0.618 -0.618 -6.18   0.   ]
# After  Step: 19, Action: Dropoff, Reward: -10, Q[1974] 	[-0.618 -0.618 -0.618 -0.618 -6.18  -6.18 ]
# --------
# Final State = 2418
# Solved in 4735 Steps with a total reward of -10717
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (Dropoff)
# ['South', 'North', 'East', 'West', 'Pickup', 'Dropoff']
# [-0.618 -0.618 -0.618 -0.618 -6.18  12.36 ]

# %% [markdown]
# First (#1): The agent starts by choosing an action with the highest Q value for the current state using argmax. Argmax will return the index/action with the highest value for that state. Initially, our Q table will be all zeros. But, after every step, the Q values for state-action pairs will be updated.
#
# Second (#2): The agent then takes action and we store the future state as state2 (S t+1). This will allow the agent to compare the previous state to the new state.
#
# Third (#3): We update the state-action pair (St , At) for Q using the reward, and the max Q value for state2 (S t+1). This update is done using the action value formula (based upon the Bellman equation) and allows state-action pairs to be updated in a recursive fashion (based on future values). See the following Figure for the value iteration update.
#
# <img src="images/qlearn.png">

# %%
print str(np.count_nonzero(Q)) + " / " + str(n_states * n_actions)
# Out:
# 2050 / 15120

# %% [markdown]
# ### Let's run over multiple episodes so that we can converge on an optimal policy

# %%
episodes = 10000
rewardTracker = []

G = 0
alpha = 0.618

for episode in range(1,episodes+1):
    done = False
    G, reward = 0,0

    state = env.reset()

    while done != True:
        action = np.argmax(Q[state]) 
        state2, reward, done, info = env.step(action) 
        Q[state,action] += alpha * ((reward + (np.max(Q[state2]))  - Q[state,action]))
        G += reward
        state = state2
    
    if episode % 100 == 0:
        print('Episode {} Total Reward: {}'.format(episode,G))
    
print str(np.count_nonzero(Q)) + " / " + str(n_states * n_actions)
# Out:
# Episode 100 Total Reward: -14
# Episode 200 Total Reward: -3
# Episode 300 Total Reward: 5
# Episode 400 Total Reward: -1
# Episode 500 Total Reward: -10
# Episode 600 Total Reward: 6
# Episode 700 Total Reward: 8
# Episode 800 Total Reward: -16
# Episode 900 Total Reward: -6
# Episode 1000 Total Reward: 6
# Episode 1100 Total Reward: 1
# Episode 1200 Total Reward: 6
# Episode 1300 Total Reward: 0
# Episode 1400 Total Reward: 2
# Episode 1500 Total Reward: 4
# Episode 1600 Total Reward: -8
# Episode 1700 Total Reward: -6
# Episode 1800 Total Reward: -3
# Episode 1900 Total Reward: 5
# Episode 2000 Total Reward: 3
# Episode 2100 Total Reward: 4
# Episode 2200 Total Reward: -5
# Episode 2300 Total Reward: 9
# Episode 2400 Total Reward: 1
# Episode 2500 Total Reward: 5
# Episode 2600 Total Reward: 2
# Episode 2700 Total Reward: 3
# Episode 2800 Total Reward: 6
# Episode 2900 Total Reward: 2
# Episode 3000 Total Reward: 7
# Episode 3100 Total Reward: 6
# Episode 3200 Total Reward: 4
# Episode 3300 Total Reward: 4
# Episode 3400 Total Reward: 1
# Episode 3500 Total Reward: 3
# Episode 3600 Total Reward: 5
# Episode 3700 Total Reward: -16
# Episode 3800 Total Reward: -2
# Episode 3900 Total Reward: 1
# Episode 4000 Total Reward: 2
# Episode 4100 Total Reward: 7
# Episode 4200 Total Reward: -2
# Episode 4300 Total Reward: 3
# Episode 4400 Total Reward: 2
# Episode 4500 Total Reward: 7
# Episode 4600 Total Reward: 7
# Episode 4700 Total Reward: -5
# Episode 4800 Total Reward: 3
# Episode 4900 Total Reward: 1
# Episode 5000 Total Reward: 8
# Episode 5100 Total Reward: -12
# Episode 5200 Total Reward: 1
# Episode 5300 Total Reward: 1
# Episode 5400 Total Reward: 1
# Episode 5500 Total Reward: -8
# Episode 5600 Total Reward: -3
# Episode 5700 Total Reward: 9
# Episode 5800 Total Reward: 8
# Episode 5900 Total Reward: 6
# Episode 6000 Total Reward: -7
# Episode 6100 Total Reward: 2
# Episode 6200 Total Reward: 2
# Episode 6300 Total Reward: -1
# Episode 6400 Total Reward: -12
# Episode 6500 Total Reward: 0
# Episode 6600 Total Reward: -4
# Episode 6700 Total Reward: 2
# Episode 6800 Total Reward: -3
# Episode 6900 Total Reward: 0
# Episode 7000 Total Reward: -10
# Episode 7100 Total Reward: -4
# Episode 7200 Total Reward: 2
# Episode 7300 Total Reward: 7
# Episode 7400 Total Reward: -7
# Episode 7500 Total Reward: 2
# Episode 7600 Total Reward: 3
# Episode 7700 Total Reward: 3
# Episode 7800 Total Reward: -4
# Episode 7900 Total Reward: 7
# Episode 8000 Total Reward: -7
# Episode 8100 Total Reward: 4
# Episode 8200 Total Reward: 1
# Episode 8300 Total Reward: -7
# Episode 8400 Total Reward: 3
# Episode 8500 Total Reward: 1
# Episode 8600 Total Reward: -5
# Episode 8700 Total Reward: 4
# Episode 8800 Total Reward: 8
# Episode 8900 Total Reward: 3
# Episode 9000 Total Reward: 3
# Episode 9100 Total Reward: 7
# Episode 9200 Total Reward: 7
# Episode 9300 Total Reward: 5
# Episode 9400 Total Reward: 9
# Episode 9500 Total Reward: -5
# Episode 9600 Total Reward: -8
# Episode 9700 Total Reward: 1
# Episode 9800 Total Reward: 6
# Episode 9900 Total Reward: 3
# Episode 10000 Total Reward: 6
# 12096 / 15120

# %% [markdown]
# ### Now that we have learned the optimal Q Values we have developed an optimal policy and have no need to train the agent anymore

# %%
state = env.reset()

done = None

while done != True:
    # We simply take the action with the highest Q Value
    action = np.argmax(Q[state])
    state, reward, done, info = env.step(action)
    env.render()
# Out:
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (South)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (West)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (West)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (West)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (Pickup)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : :_: : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : :_: : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (East)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O|_|O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : :_: : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : :_: |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (East)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : :_|O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (East)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (North)
# +-----------------+
# |O|O| : : : : :G: |
# |O|O| |O| |O| |O| |
# |O| : |O| |O| |O| |
# | : |O|O| : : : : |
# | |O|O|O|O|O| |O| |
# | : :R: : : : :O: |
# | |O|O|O| |O|O|O| |
# | |O| : : |O| : : |
# | |O| |O|O|O|B|O| |
# | : : : : : : |O| |
# | |O| |O| |O| |O| |
# | : : : : : : |O| |
# | |O| |O| |O|O|O| |
# | : : :Y: : : : : |
# +-----------------+
#   (Dropoff)
